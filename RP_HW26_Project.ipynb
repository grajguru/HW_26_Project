# %% [markdown]
# # Radiative Processes: Project
# ## A Study of Synchrotron Emission in Astrophysics

# %% [markdown]
# Begin by installing and importing the necessary python libraries

# %%
import sys
import numpy as np
from ipywidgets import interact, interactive
import ipywidgets as widgets

# !{sys.executable} -m pip install --quiet matplotlib

import matplotlib.pyplot as plt

# %% [markdown]
# ### Power Distribution of electrons undergoing Synchrotron Emision

# %% [markdown]
# Define some routines for the notebook.

# %% [markdown]
# Non-relativistic

# %% [markdown]
# Larmor's Formula:\
# $P=\frac{2}{3}\frac{q^2 a^2}{c^3}$ (cgs)

# %% [markdown]
# Relativistic

# %% [markdown]
# Added from test.py shared by Prof. Meyer \
# To be extended in this projectto relativistic case

# %%
elev=40
azim = -10
roll = 10
def plot_dif(elev,azim,roll):
    fig = plt.figure()
    ax = fig.add_subplot(projection='3d')

    # Make data
    u = np.linspace(0, 2 * np.pi, 100)
    v = np.linspace(0, np.pi, 100)
    x = 10 * np.outer(np.cos(u), np.sin(v)*np.power(np.sin(v), 2))
    y = 10 * np.outer(np.sin(u), np.sin(v)*np.power(np.sin(v), 2))
    z = 10 * np.outer(np.ones(np.size(u)), np.cos(v)*np.power(np.sin(v), 2))

    # Plot the surface
    ax.plot_surface(x, y, z)

    # Set an equal aspect ratio
    ax.set_aspect('auto')
    ax.view_init(elev, azim, roll)

    plt.show()

interact(plot_dif, elev = widgets.BoundedFloatText(value=40, min=1, max = 100, step=10,
                                                       descriptions='elev', disabled=False),\
         azim = widgets.BoundedFloatText(value=-10, min=0, max =360, step=10,
                                                       descriptions='azim', disabled=False), \
         roll = widgets.BoundedFloatText(value=10, min=1, max = 100, step=10,
                                                       descriptions='roll', disabled=False))
# Out:
# interactive(children=(BoundedFloatText(value=40.0, description='elev', min=1.0, step=10.0), BoundedFloatText(v…
# <function __main__.plot_dif(elev, azim, roll)>

# %% [markdown]
# ### Angular Distribution of Power Distribution of electrons undergoing Synchrotron Emision

# %% [markdown]
# Define some routines for the notebook.

# %% [markdown]
# ### Parameter Dependence of Power Distribution of electrons undergoing Synchrotron Emision

# %% [markdown]
# Define some routines for the notebook.
